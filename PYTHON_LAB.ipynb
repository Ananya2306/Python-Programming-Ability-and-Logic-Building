# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananya2306/Python-Programming-Ability-and-Logic-Building/blob/main/PYTHON_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# datatype -
#
# no memory it contains
# no character datatype
#
# number -
#
# int - a=1
#
# float - a=1.22
#
# complex -
#   - in loops we use i
#   so system wil get error so it takes imaginary no. j
#
# none -
#
# sequence -
#
# String - '' , "" """ """,
#
# tuple
#
# list
#
#
# set

# %%
a = 1+2j
print(type(a))
# Out:
# <class 'complex'>

# %% [markdown]
# whenever u r taking input of user val converted into string

# %%
s = input("Enter val")
print(s)
print(type(s))
# Out:
# Enter val1
# 1
# <class 'str'>

# %%
s = int(input("Enter val"))
print(s)
print(type(s))
# Out:
# Enter val1
# 1
# <class 'int'>

# %%
s = float(input("Enter val"))
print(s)
print(type(s))
# Out:
# Enter val2
# 2.0
# <class 'float'>

# %%
s = complex(input("Enter val"))
print(s)
print(type(s))

# %% [markdown]
# None
#
# for future use
# no garbage value

# %%
a=None
print(type(a))
# Out:
# <class 'NoneType'>

# %%
m = 20
print(id(m))
# Out:
# 11654984

# %% [markdown]
# they don't have pointers cause they have special values

# %%
a,b,c,d = 10,20,10,20
print(id(a))
print(id(b))
print(id(c))
print(id(d))
# Out:
# 11654664
# 11654984
# 11654664
# 11654984

# %%
a = 'a'
b = "ab"
c = """abc"""
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# no mutliline comments
#
# DOC Strings - ''' ''' / """ """ - when we need the use multiline comments - doc string is not integrated in python

# %%
'''hi hello'''
# Out:
# 'hi hello'

# %%
""" heeeellllloooooooooooooooooooooo"""
# Out:
# ' heeeellllloooooooooooooooooooooo'

# %%
d = "hello"
print(d[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3767570380.py in <cell line: 0>()
#       1 d = "hello"
# ----> 2 print(d[5])
#
# IndexError: string index out of range

# %% [markdown]
# For array concept of ARRAY -> Numpy

# %%
import numpy as np
a = np.array([1,2,3,4])
print(a)
print(type(a))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %% [markdown]
# Indexing
#
# - POSITIVE
#   - S -> 0
#   - sum -> n-1
#
#
# - NEGATIVE
#   - S -> -1
#   - sum -> -n
#
#   n -> length of the string

# %%
l = [1,1.23,"hello",False,3+2j]
print(type(l[3]))
print(l)
print(id(l))
# Out:
# <class 'bool'>
# [1, 1.23, 'hello', False, (3+2j)]
# 137988982640576

# %% [markdown]
# WRITE A PROGRAM TO DEMO THE CONCEPT OF STRING

# %% [markdown]
# SLICING
# - syntax of 3
# [start : stop : step]
# a = "hello"
# print( a[0:3:2])

# %%
a = "hello"
print( a[0:3:2])
print( a[-1:-5:-1])
# Out:
# hl
# olle

# %% [markdown]
# write a program
# str - INDIA
# to reverse string without using the concept of slicing

# %%
s = "INDIA"
reversed_s = ""
for char in s:
    reversed_s = char + reversed_s
print(f"Original string: {s}")
print(f"Reversed string: {reversed_s}")
# Out:
# Original string: INDIA
# Reversed string: AIDNI

# %% [markdown]
# list
# - colletion of items / elements enclosed bet. []
# - allows to store all the data types
# - li = [1,1.23,"hello", False, 3+2j]
#
# array
# string
# func
# pointer
# structures
# unioun ()
#
# diff datatypes
# higher memory
#
# array list
# array structure
# structure union
#
# int - 4
# float - 4
# char
#  and
# structures
# primary
# define
# user define
